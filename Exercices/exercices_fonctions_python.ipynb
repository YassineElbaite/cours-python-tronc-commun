# %% [markdown]
# # 🐍 Les Fonctions en Python — Feuille d'Exercices
# ### Tronc Commun | Lycée
#
#
#
# > 📌 **Instructions :**
# > - Lisez bien chaque exercice avant de commencer
# > - Écrivez votre code dans la cellule prévue sous chaque exercice
# > - Exécutez votre code avec **Shift + Entrée** pour tester
# > - Ne copiez pas — essayez d'abord par vous-même ! 💪
#
# ---

# %% [markdown]
# ---
# ## ✏️ Exercice 1 — Ma première fonction
#
# **Créez une fonction appelée `ma_presentation` qui affiche :**
# - Votre prénom
# - Votre classe
# - Votre matière préférée
#
# Ensuite, **appelez** cette fonction **2 fois**.
#
# 💡 *Rappel de la syntaxe :*
# ```python
# def nom_fonction():
#     print("quelque chose")
# ```

# %%
# ✏️ Exercice 1 — Écrivez votre code ici :

# %% [markdown]
# ---
# ## ✏️ Exercice 2 — Paramètres
#
# **Créez une fonction `afficher_score` qui reçoit :**
# - Le **nom** d'un joueur de football
# - Son **nombre de buts**
#
# La fonction doit afficher : `Joueur : [nom] — Buts : [buts] ⚽`
#
# **Testez avec :**
# - Benzema → 15 buts
# - Hakimi → 7 buts
# - Boufal → 10 buts
#
# 💡 *Rappel :*
# ```python
# def nom_fonction(parametre1, parametre2,..........):
#     print(parametre1, parametre2)
# ```

# %%
# ✏️ Exercice 2 — Écrivez votre code ici :

def -------(joueur,-------- ):
    print("Joueur :", joueur, "— Buts :", buts, "⚽")

afficher_sco--("-------", 15)
afficher_score("Hakimi", 7)
----------------------------

# %% [markdown]
# # 🧠 Exercice 3: Calcul de la moyenne
# ## 🎯 Objectif :
#
# Créer une fonction qui permet de calculer la moyenne de 3 notes en utilisant return

# %%
#votre Code
#  Calculer la moyenne de 3 notes

# %% [markdown]
# ---
# ## ✏️ Exercice 4 — Conditions dans une fonction
#
# **Créez une fonction `verifier_age` qui :**
# - Reçoit l'**âge** d'une personne
# - Retourne `"Mineur"` si l'âge est **moins de 18 ans**
# - Retourne `"Majeur"` si l'âge est **18 ans ou plus**
#
# **Testez avec les âges :** 15, 18, 21, 10
#
# 💡 *Rappel :*
# ```python
# def ma_fonction(x):
#     if x > 0:
#         return "positif"
#     else:
#         return "négatif"
# ```

# %%
# ✏️ Exercice 4 — Écrivez votre code ici :

# %% [markdown]
# ---
# ## 🏆 Défi 1 — Fonction `addition`
#
# Créez une fonction `addition(a, b)` qui **retourne** la somme de deux nombres.
#
# Testez avec : `addition(3, 4)` → doit afficher **7**

# %%
# 🏆 Défi 1 — Écrivez votre code ici :

# %% [markdown]
# ---
# ## Mini Calculatrice
#
# Créez **4 fonctions** :
# - `addition(a, b)` → retourne `a + b`
# - `soustraction(a, b)` → retourne `a - b`
# - `multiplication(a, b)` → retourne `a * b`
# - `division(a, b)` → retourne `a / b` *(attention : vérifiez que b ≠ 0 !)*
#
# Ensuite testez chaque fonction avec des nombres de votre choix.
#
# 🌟 *Félicitations si vous arrivez jusqu'ici !*

# %%
# ⭐ Défi Bonus — Écrivez votre code ici :

# %% [markdown]
# ---
#
# ## 📊 Mon bilan personnel
#
# Choisir ce que vous avez réussi aujourd'hui :
#
# - [1 ] Je sais créer une fonction avec `def`
# - [2 ] Je sais appeler une fonction
# - [3 ] Je sais utiliser des paramètres
# - [4 ] Je sais utiliser `return`
# - [5 ] Je sais mettre des conditions dans une fonction
# - [6 ] J'ai réussi tous les défis 🏆
# - [7 ] J'ai réussi le défi Bonus ⭐
#
# ---
#
# > 💬 **Une question ou une difficulté ?** Notez-la ici :
# >
# > _________________________________________________________________
# >
# > _________________________________________________________________
#
# ---
# *Bonne chance ! 🚀 — Cours de Python | Tronc Commun*
